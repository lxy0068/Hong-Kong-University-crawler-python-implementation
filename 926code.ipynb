# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from io import StringIO

url = 'https://en.wikipedia.org/wiki/2022_Asian_Games_medal_table'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'wikitable'})
table_str = str(table)
table_io = StringIO(table_str)  

df = pd.read_html(table_io)[0]

df.columns = ['Rank', 'Nation', 'Gold', 'Silver', 'Bronze', 'Total']
df['Nation'] = df['Nation'].str.replace(r'\*', '', regex=True)

df = df[pd.to_numeric(df['Rank'], errors='coerce').notna()]
df['Rank'] = df['Rank'].astype(int)
df['Gold'] = df['Gold'].fillna(0).astype(int)
df['Silver'] = df['Silver'].fillna(0).astype(int)
df['Bronze'] = df['Bronze'].fillna(0).astype(int)

q1df = pd.melt(df[['Rank', 'Nation', 'Gold', 'Silver', 'Bronze']],
               id_vars=['Rank', 'Nation'], 
               var_name='Medal', 
               value_name='Count')

q1df.rename(columns={'Nation': 'Team'}, inplace=True)

q1df['Medal'] = pd.Categorical(q1df['Medal'], categories=['Gold', 'Silver', 'Bronze'], ordered=True)

q1df = q1df.sort_values(by=['Rank', 'Team', 'Medal']).reset_index(drop=True)

q1df['Rank'] = q1df['Rank'].astype(int)
q1df['Count'] = q1df['Count'].astype(int)
q1df['Team'] = q1df['Team'].astype(str)
q1df['Medal'] = q1df['Medal'].astype(str)

q1df.to_csv('Q1_medal.csv', index=False)

# %%
q1df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    123 non-null    int32
#  1   Team    123 non-null    object
#  2   Medal   123 non-null    object
#  3   Count   123 non-null    int32
# dtypes: int32(2), object(2)
# memory usage: 3.0+ KB

# %%
q1df.head(6)
# Out:
#    Rank   Team   Medal  Count
# 0     1  China    Gold    201
# 1     1  China  Silver    111
# 2     1  China  Bronze     71
# 3     2  Japan    Gold     52
# 4     2  Japan  Silver     67
# 5     2  Japan  Bronze     69

# %%
q1df.tail(6)
# Out:
#      Rank       Team   Medal  Count
# 117    38  Palestine    Gold      0
# 118    38  Palestine  Silver      0
# 119    38  Palestine  Bronze      1
# 120    38      Syria    Gold      0
# 121    38      Syria  Silver      0
# 122    38      Syria  Bronze      1

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://realpython.github.io/fake-jobs/'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

positions = []
companies = []
cities = []
states = []

jobs = soup.find_all('div', class_='card-content')

for job in jobs:
    position = job.find('h2', class_='title').text.strip()
    company = job.find('h3', class_='subtitle').text.strip()
    location = job.find('p', class_='location').text.strip()
    
    city, state = location.rsplit(',', 1)
    city = city.strip()
    state = state.strip()
    
    positions.append(position)
    companies.append(company)
    cities.append(city)
    states.append(state)
q2df = pd.DataFrame({
    'position': positions,
    'company': companies,
    'city': cities,
    'state': states
})

q2sample = q2df[(q2df['state'] == 'AA') & (q2df['position'].str.contains('engineer', case=False))]

q2df.to_csv('Q2_jobs.csv', index=False)

# %%
q2df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   position  100 non-null    object
#  1   company   100 non-null    object
#  2   city      100 non-null    object
#  3   state     100 non-null    object
# dtypes: object(4)
# memory usage: 3.3+ KB

# %%
q2df.head(3)
# Out:
#                   position                     company              city state
# 0  Senior Python Developer    Payne, Roberts and Davis       Stewartbury    AA
# 1          Energy engineer            Vasquez-Davidson  Christopherville    AA
# 2          Legal executive  Jackson, Chambers and Levy   Port Ericaburgh    AA

# %%
q2df.tail(3)
# Out:
#                   position                    company           city state
# 97  Database administrator             Yates-Ferguson     Port Susan    AE
# 98      Furniture designer            Ortega-Lawrence  North Tiffany    AA
# 99             Ship broker  Fuentes, Walls and Castro  Michelleville    AP

# %%
q2sample
# Out:
#                                position                     company  \
# 1                       Energy engineer            Vasquez-Davidson
# 28                  Structural engineer                 Pierce-Long
# 32                   Broadcast engineer  Morgan, Butler and Bennett
# 48  Engineer, broadcasting (operations)                  Taylor PLC
#
#                 city state
# 1   Christopherville    AA
# 28       Herbertside    AA
# 32          Loribury    AA
# 48          Gileston    AA

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

url = 'https://www.peakbagger.com/list.aspx?lid=5651'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find('table', {'class': 'gray'})

if table is None:
    print("Error: Could not find the table. Please check the HTML structure and adjust the selector.")
else:
    print("Table found successfully!")


names, regions, elevs, ids, lats, longs = [], [], [], [], [], []

for i, row in enumerate(table.find_all('tr')[1:]):
    cols = row.find_all('td')
    
    if len(cols) >= 4:
        name = cols[1].text.strip()
        region = cols[2].text.strip()
        elev = int(cols[3].text.strip()) 
        peak_url = cols[1].find('a')['href']
        peak_id = peak_url.split('pid=')[1]

        peak_response = requests.get(f'https://www.peakbagger.com/{peak_url}')
        peak_soup = BeautifulSoup(peak_response.content, 'html.parser')

        lat_long_row = peak_soup.find(string='Latitude/Longitude (WGS84)')
        if lat_long_row:
            lat_long_td = lat_long_row.find_next('td')
            lat_long_text = lat_long_td.get_text(strip=True)

            print(f"Extracted lat/long text for {name}: {lat_long_text}")

            try:
                lat_long_parts = lat_long_text.split(',')
                lat = float(lat_long_parts[0].strip())
                long = float(lat_long_parts[1].strip().split()[0])  
            except (ValueError, IndexError) as e:
                lat, long = None, None
                print(f"Error parsing lat/long for {name} (URL: https://www.peakbagger.com/{peak_url}): {e}")
        else:
            lat, long = None, None
            print(f"Lat/long not found for {name} (URL: https://www.peakbagger.com/{peak_url})")

        names.append(name)
        regions.append(region)
        elevs.append(elev)
        ids.append(peak_id)
        lats.append(lat)
        longs.append(long)

    if (i + 1) % 10 == 0:
        print(f"Extracted data for {i + 1} mountains so far...")

    time.sleep(1)

q3df = pd.DataFrame({
    'name': names,
    'region': regions,
    'elev': elevs,
    'id': ids,
    'lat': lats,
    'long': longs
})

q3df.drop_duplicates(subset='id', inplace=True)

def categorize_elevation(elev):
    if elev >= 0 and elev < 1000:
        return 'Cat 1'
    elif elev >= 1000 and elev < 2000:
        return 'Cat 2'
    elif elev >= 2000 and elev < 3000:
        return 'Cat 3'
    else:
        return 'Cat 4'

q3df['elev_cat'] = q3df['elev'].apply(categorize_elevation)

q3df.to_csv('Q3_mountains.csv', index=False)
# Out:
# Table found successfully!
# Extracted lat/long text for Fuji-san: 35.360638, 138.727347 (Dec Deg)35° 21' 38'' N, 138° 43' 38'' E (DMS)293513 E, 3915408 N, Zone 54 (UTM)
# Extracted lat/long text for Fuji-san: 35.360638, 138.727347 (Dec Deg)35° 21' 38'' N, 138° 43' 38'' E (DMS)293513 E, 3915408 N, Zone 54 (UTM)
# Extracted lat/long text for Kita-dake: 35.674537, 138.238833 (Dec Deg)35° 40' 28'' N, 138° 14' 20'' E (DMS)250093 E, 3951364 N, Zone 54 (UTM)
# Extracted lat/long text for Hotaka-dake: 36.289203, 137.647986 (Dec Deg)36° 17' 21'' N, 137° 38' 53'' E (DMS)737808 E, 4019280 N, Zone 53 (UTM)
# Extracted lat/long text for Aino-dake: 35.646037, 138.228292 (Dec Deg)35° 38' 46'' N, 138° 13' 42'' E (DMS)249049 E, 3948229 N, Zone 54 (UTM)
# Extracted lat/long text for Yariga-take: 36.34198, 137.647625 (Dec Deg)36° 20' 31'' N, 137° 38' 51'' E (DMS)737615 E, 4025135 N, Zone 53 (UTM)
# Extracted lat/long text for Warusawa-dake: 35.500736, 138.182417 (Dec Deg)35° 30' 3'' N, 138° 10' 57'' E (DMS)244433 E, 3932226 N, Zone 54 (UTM)
# Extracted lat/long text for Akaishi-dake: 35.461232, 138.157347 (Dec Deg)35° 27' 40'' N, 138° 9' 26'' E (DMS)242032 E, 3927908 N, Zone 54 (UTM)
# Extracted lat/long text for Ontake-san: 35.892995, 137.480417 (Dec Deg)35° 53' 35'' N, 137° 28' 50'' E (DMS)723878 E, 3974922 N, Zone 53 (UTM)
# Extracted lat/long text for Shiomi-dake: 35.573822, 138.183069 (Dec Deg)35° 34' 26'' N, 138° 10' 59'' E (DMS)244724 E, 3940333 N, Zone 54 (UTM)
# Extracted data for 10 mountains so far...
# Extracted lat/long text for Senjoga-dake: 35.720077, 138.183556 (Dec Deg)35° 43' 12'' N, 138° 11' 1'' E (DMS)245234 E, 3956559 N, Zone 54 (UTM)
# Extracted lat/long text for Norikura-dake: 36.106514, 137.553611 (Dec Deg)36° 6' 23'' N, 137° 33' 13'' E (DMS)729864 E, 3998782 N, Zone 53 (UTM)
# Extracted lat/long text for Tate-yama: 36.575994, 137.619778 (Dec Deg)36° 34' 34'' N, 137° 37' 11'' E (DMS)734409 E, 4051032 N, Zone 53 (UTM)
# Extracted lat/long text for Hijiri-dake: 35.422554, 138.139625 (Dec Deg)35° 25' 21'' N, 138° 8' 23'' E (DMS)240299 E, 3923663 N, Zone 54 (UTM)
# Extracted lat/long text for Tsurugi-dake: 36.62325, 137.61687 (Dec Deg)36° 37' 24'' N, 137° 37' 1'' E (DMS)734006 E, 4056269 N, Zone 53 (UTM)
# Extracted lat/long text for Suisho-dake: 36.426322, 137.602762 (Dec Deg)36° 25' 35'' N, 137° 36' 10'' E (DMS)733336 E, 4034384 N, Zone 53 (UTM)
# Extracted lat/long text for Kaikomaga-take: 35.757933, 138.236814 (Dec Deg)35° 45' 29'' N, 138° 14' 13'' E (DMS)250171 E, 3960622 N, Zone 54 (UTM)
# Extracted lat/long text for Kisokomaga-take: 35.789557, 137.804559 (Dec Deg)35° 47' 22'' N, 137° 48' 16'' E (DMS)753470 E, 3964237 N, Zone 53 (UTM)
# Extracted lat/long text for Shirouma-dake: 36.758578, 137.7586 (Dec Deg)36° 45' 31'' N, 137° 45' 31'' E (DMS)746250 E, 4071640 N, Zone 53 (UTM)
# Extracted lat/long text for Yakushi-dake: 36.468856, 137.544786 (Dec Deg)36° 28' 8'' N, 137° 32' 41'' E (DMS)728012 E, 4038964 N, Zone 53 (UTM)
# Extracted data for 20 mountains so far...
# Extracted lat/long text for Washiba-dake: 36.402967, 137.605227 (Dec Deg)36° 24' 11'' N, 137° 36' 19'' E (DMS)733627 E, 4031798 N, Zone 53 (UTM)
# Extracted lat/long text for Yatsuga-take: 35.970811, 138.370057 (Dec Deg)35° 58' 15'' N, 138° 22' 12'' E (DMS)262856 E, 3983909 N, Zone 54 (UTM)
# Extracted lat/long text for Kasaga-dake: 36.315502, 137.550417 (Dec Deg)36° 18' 56'' N, 137° 33' 2'' E (DMS)728967 E, 4021962 N, Zone 53 (UTM)
# Extracted lat/long text for Kashima-yariga-take: 36.624555, 137.747015 (Dec Deg)36° 37' 28'' N, 137° 44' 49'' E (DMS)745642 E, 4056739 N, Zone 53 (UTM)
# Extracted lat/long text for Utsugi-dake: 35.719, 137.817073 (Dec Deg)35° 43' 8'' N, 137° 49' 1'' E (DMS)754827 E, 3956441 N, Zone 53 (UTM)
# Extracted lat/long text for Jonen-dake: 36.325522, 137.727621 (Dec Deg)36° 19' 32'' N, 137° 43' 39'' E (DMS)744848 E, 4023509 N, Zone 53 (UTM)
# Extracted lat/long text for Hoo-zan: 35.701756, 138.304573 (Dec Deg)35° 42' 6'' N, 138° 18' 16'' E (DMS)256127 E, 3954219 N, Zone 54 (UTM)
# Extracted lat/long text for Kurobegoro-dake: 36.392578, 137.539883 (Dec Deg)36° 23' 33'' N, 137° 32' 24'' E (DMS)727796 E, 4030489 N, Zone 53 (UTM)
# Extracted lat/long text for Goryu-dake: 36.658425, 137.752664 (Dec Deg)36° 39' 30'' N, 137° 45' 10'' E (DMS)746040 E, 4060512 N, Zone 53 (UTM)
# Extracted lat/long text for Haku-san: 36.155089, 136.771435 (Dec Deg)36° 9' 18'' N, 136° 46' 17'' E (DMS)659350 E, 4002604 N, Zone 53 (UTM)
# Extracted data for 30 mountains so far...
# Extracted lat/long text for Kinpu-san: 35.871611, 138.625453 (Dec Deg)35° 52' 18'' N, 138° 37' 32'' E (DMS)285622 E, 3972312 N, Zone 54 (UTM)
# Extracted lat/long text for Tekari-dake: 35.338189, 138.083786 (Dec Deg)35° 20' 17'' N, 138° 5' 2'' E (DMS)234952 E, 3914451 N, Zone 54 (UTM)
# Extracted lat/long text for Shirane-san: 36.798589, 139.375886 (Dec Deg)36° 47' 55'' N, 139° 22' 33'' E (DMS)355107 E, 4073760 N, Zone 54 (UTM)
# Extracted lat/long text for Asama-yama: 36.40656, 138.522941 (Dec Deg)36° 24' 24'' N, 138° 31' 23'' E (DMS)277879 E, 4031894 N, Zone 54 (UTM)
# Extracted lat/long text for Tateshina-yama: 36.103722, 138.295076 (Dec Deg)36° 6' 13'' N, 138° 17' 42'' E (DMS)256503 E, 3998841 N, Zone 54 (UTM)
# Extracted lat/long text for Nantai-san: 36.7651, 139.490817 (Dec Deg)36° 45' 54'' N, 139° 29' 27'' E (DMS)365302 E, 4069877 N, Zone 54 (UTM)
# Extracted lat/long text for Kobushiga-take: 35.909044, 138.728922 (Dec Deg)35° 54' 33'' N, 138° 43' 44'' E (DMS)295061 E, 3976243 N, Zone 54 (UTM)
# Extracted lat/long text for Hiuchi-yama: 36.9227, 138.068106 (Dec Deg)36° 55' 22'' N, 138° 4' 5'' E (DMS)238836 E, 4090313 N, Zone 54 (UTM)
# Extracted lat/long text for Yake-dake: 36.226909, 137.587028 (Dec Deg)36° 13' 37'' N, 137° 35' 13'' E (DMS)732517 E, 4012220 N, Zone 53 (UTM)
# Extracted lat/long text for Myoko-san: 36.8913, 138.113428 (Dec Deg)36° 53' 29'' N, 138° 6' 48'' E (DMS)242768 E, 4086706 N, Zone 54 (UTM)
# Extracted data for 40 mountains so far...
# Extracted lat/long text for Hiuchiga-take: 36.955111, 139.285308 (Dec Deg)36° 57' 18'' N, 139° 17' 7'' E (DMS)347337 E, 4091266 N, Zone 54 (UTM)
# Extracted lat/long text for Azumaya-san: 36.541733, 138.412848 (Dec Deg)36° 32' 30'' N, 138° 24' 46'' E (DMS)268408 E, 4047152 N, Zone 54 (UTM)
# Extracted lat/long text for Takazuma: 36.800078, 138.051909 (Dec Deg)36° 48' 0'' N, 138° 3' 7'' E (DMS)236972 E, 4076750 N, Zone 54 (UTM)
# Extracted lat/long text for Asahi-dake: 43.663556, 142.854085 (Dec Deg)43° 39' 49'' N, 142° 51' 15'' E (DMS)649488 E, 4836176 N, Zone 54 (UTM)
# Extracted lat/long text for Chokai-zan: 39.099396, 140.048861 (Dec Deg)39° 5' 58'' N, 140° 2' 56'' E (DMS)417754 E, 4328237 N, Zone 54 (UTM)
# Extracted lat/long text for Mizugaki: 35.8935, 138.592104 (Dec Deg)35° 53' 37'' N, 138° 35' 32'' E (DMS)282670 E, 3974814 N, Zone 54 (UTM)
# Extracted lat/long text for Shibutsu-san: 36.903467, 139.173217 (Dec Deg)36° 54' 12'' N, 139° 10' 24'' E (DMS)337247 E, 4085722 N, Zone 54 (UTM)
# Extracted lat/long text for Ena-san: 35.443045, 137.597859 (Dec Deg)35° 26' 35'' N, 137° 35' 52'' E (DMS)735801 E, 3925278 N, Zone 53 (UTM)
# Extracted lat/long text for Kusatsu-shirane-san: 36.64394, 138.527671 (Dec Deg)36° 38' 38'' N, 138° 31' 40'' E (DMS)278981 E, 4058222 N, Zone 54 (UTM)
# Extracted lat/long text for Hotaka-yama: 36.805211, 139.132578 (Dec Deg)36° 48' 19'' N, 139° 7' 57'' E (DMS)333413 E, 4074891 N, Zone 54 (UTM)
# Extracted data for 50 mountains so far...
# Extracted lat/long text for Naeba-san: 36.845978, 138.690286 (Dec Deg)36° 50' 46'' N, 138° 41' 25'' E (DMS)294061 E, 4080276 N, Zone 54 (UTM)
# Extracted lat/long text for Sukai-san: 36.689889, 139.337006 (Dec Deg)36° 41' 24'' N, 139° 20' 13'' E (DMS)351429 E, 4061760 N, Zone 54 (UTM)
# Extracted lat/long text for Hiraga-dake: 37.002067, 139.170907 (Dec Deg)37° 0' 7'' N, 139° 10' 15'' E (DMS)337251 E, 4096665 N, Zone 54 (UTM)
# Extracted lat/long text for Tomuraushi: 43.5271, 142.848747 (Dec Deg)43° 31' 38'' N, 142° 50' 55'' E (DMS)649395 E, 4821011 N, Zone 54 (UTM)
# Extracted lat/long text for Komaga-dake: 37.047544, 139.353519 (Dec Deg)37° 2' 51'' N, 139° 21' 13'' E (DMS)353588 E, 4101414 N, Zone 54 (UTM)
# Extracted lat/long text for Iide-san: 37.854867, 139.707044 (Dec Deg)37° 51' 18'' N, 139° 42' 25'' E (DMS)386256 E, 4190500 N, Zone 54 (UTM)
# Extracted lat/long text for Tokachi-dake: 43.417822, 142.686269 (Dec Deg)43° 25' 4'' N, 142° 41' 11'' E (DMS)636511 E, 4808596 N, Zone 54 (UTM)
# Extracted lat/long text for Daibosatsu-rei: 35.748778, 138.8455 (Dec Deg)35° 44' 56'' N, 138° 50' 44'' E (DMS)305191 E, 3958225 N, Zone 54 (UTM)
# Extracted lat/long text for Poroshiri-dake: 42.719411, 142.682866 (Dec Deg)42° 43' 10'' N, 142° 40' 58'' E (DMS)637792 E, 4731030 N, Zone 54 (UTM)
# Extracted lat/long text for Iwate-san: 39.852611, 141.001032 (Dec Deg)39° 51' 9'' N, 141° 0' 4'' E (DMS)500088 E, 4411399 N, Zone 54 (UTM)
# Extracted data for 60 mountains so far...
# Extracted lat/long text for Nishi-Azuma-yama: 37.738178, 140.140714 (Dec Deg)37° 44' 17'' N, 140° 8' 27'' E (DMS)424289 E, 4177113 N, Zone 54 (UTM)
# Extracted lat/long text for Utsukushigahara: 36.225833, 138.107417 (Dec Deg)36° 13' 33'' N, 138° 6' 27'' E (DMS)240010 E, 4012877 N, Zone 54 (UTM)
# Extracted lat/long text for Kumotori-yama: 35.855511, 138.94389 (Dec Deg)35° 51' 20'' N, 138° 56' 38'' E (DMS)314338 E, 3969874 N, Zone 54 (UTM)
# Extracted lat/long text for Echigo-komagatake: 37.123644, 139.075233 (Dec Deg)37° 7' 25'' N, 139° 4' 31'' E (DMS)329011 E, 4110323 N, Zone 54 (UTM)
# Extracted lat/long text for Gassan: 38.549144, 140.026924 (Dec Deg)38° 32' 57'' N, 140° 1' 37'' E (DMS)415207 E, 4267195 N, Zone 54 (UTM)
# Extracted lat/long text for Ishizuchi-san: 33.767741, 133.115104 (Dec Deg)33° 46' 4'' N, 133° 6' 54'' E (DMS)325450 E, 3738000 N, Zone 53 (UTM)
# Extracted lat/long text for Tanigawa-dake: 36.8371, 138.930144 (Dec Deg)36° 50' 14'' N, 138° 55' 49'' E (DMS)315429 E, 4078801 N, Zone 54 (UTM)
# Extracted lat/long text for Makihata-yama: 36.978589, 138.964483 (Dec Deg)36° 58' 43'' N, 138° 57' 52'' E (DMS)318826 E, 4094433 N, Zone 54 (UTM)
# Extracted lat/long text for Amakazari: 36.902011, 137.962586 (Dec Deg)36° 54' 7'' N, 137° 57' 45'' E (DMS)763970 E, 4088102 N, Zone 53 (UTM)
# Extracted lat/long text for Tsurugi-san: 33.853601, 134.094235 (Dec Deg)33° 51' 13'' N, 134° 5' 39'' E (DMS)416210 E, 3746293 N, Zone 53 (UTM)
# Extracted data for 70 mountains so far...
# Extracted lat/long text for Miyanoura-dake: 30.335971, 130.504288 (Dec Deg)30° 20' 9'' N, 130° 30' 15'' E (DMS)644602 E, 3356974 N, Zone 52 (UTM)
# Extracted lat/long text for Kirigamine: 36.102911, 138.196665 (Dec Deg)36° 6' 10'' N, 138° 11' 48'' E (DMS)247640 E, 3999002 N, Zone 54 (UTM)
# Extracted lat/long text for Hayachine-san: 39.558544, 141.48873 (Dec Deg)39° 33' 31'' N, 141° 29' 19'' E (DMS)541985 E, 4378876 N, Zone 54 (UTM)
# Extracted lat/long text for Hakken-zan: 34.173667, 135.907507 (Dec Deg)34° 10' 25'' N, 135° 54' 27'' E (DMS)583637 E, 3781784 N, Zone 53 (UTM)
# Extracted lat/long text for Nasu-dake: 37.124856, 139.963098 (Dec Deg)37° 7' 29'' N, 139° 57' 47'' E (DMS)407890 E, 4109226 N, Zone 54 (UTM)
# Extracted lat/long text for Yotei-zan: 42.826611, 140.811494 (Dec Deg)42° 49' 36'' N, 140° 48' 41'' E (DMS)484592 E, 4741578 N, Zone 54 (UTM)
# Extracted lat/long text for Asahi-dake: 38.260556, 139.922272 (Dec Deg)38° 15' 38'' N, 139° 55' 20'' E (DMS)405713 E, 4235274 N, Zone 54 (UTM)
# Extracted lat/long text for Zao-san: 38.14367, 140.439363 (Dec Deg)38° 8' 37'' N, 140° 26' 22'' E (DMS)450874 E, 4221904 N, Zone 54 (UTM)
# Extracted lat/long text for Akagi-san: 36.560378, 139.193293 (Dec Deg)36° 33' 37'' N, 139° 11' 36'' E (DMS)338318 E, 4047624 N, Zone 54 (UTM)
# Extracted lat/long text for Bandai-san: 37.600989, 140.072213 (Dec Deg)37° 36' 4'' N, 140° 4' 20'' E (DMS)418102 E, 4161950 N, Zone 54 (UTM)
# Extracted data for 80 mountains so far...
# Extracted lat/long text for Kuju-san: 33.082147, 131.240849 (Dec Deg)33° 4' 56'' N, 131° 14' 27'' E (DMS)709158 E, 3662627 N, Zone 52 (UTM)
# Extracted lat/long text for Sobo-san: 32.828145, 131.347038 (Dec Deg)32° 49' 41'' N, 131° 20' 49'' E (DMS)719700 E, 3634676 N, Zone 52 (UTM)
# Extracted lat/long text for Ryokami-san: 36.023411, 138.841273 (Dec Deg)36° 1' 24'' N, 138° 50' 29'' E (DMS)305482 E, 3988701 N, Zone 54 (UTM)
# Extracted lat/long text for Rishiri-zan - Kita-mine: 45.180358, 141.241433 (Dec Deg)45° 10' 49'' N, 141° 14' 29'' E (DMS)518969 E, 5003015 N, Zone 54 (UTM)
# Extracted lat/long text for Dai-sen - Misen: 35.371039, 133.53998 (Dec Deg)35° 22' 16'' N, 133° 32' 24'' E (DMS)367370 E, 3915169 N, Zone 53 (UTM)
# Extracted lat/long text for Karakuni-dake: 31.934172, 130.861579 (Dec Deg)31° 56' 3'' N, 130° 51' 42'' E (DMS)675975 E, 3534652 N, Zone 52 (UTM)
# Extracted lat/long text for Adatara-yama: 37.621133, 140.287876 (Dec Deg)37° 37' 16'' N, 140° 17' 16'' E (DMS)437157 E, 4164019 N, Zone 54 (UTM)
# Extracted lat/long text for Odaigahara-zan: 34.185256, 136.109207 (Dec Deg)34° 11' 7'' N, 136° 6' 33'' E (DMS)602212 E, 3783253 N, Zone 53 (UTM)
# Extracted lat/long text for Rausu-dake: 44.075689, 145.122209 (Dec Deg)44° 4' 32'' N, 145° 7' 20'' E (DMS)349640 E, 4881994 N, Zone 55 (UTM)
# Extracted lat/long text for Iwaki-san: 40.655933, 140.30302 (Dec Deg)40° 39' 21'' N, 140° 18' 11'' E (DMS)441079 E, 4500797 N, Zone 54 (UTM)
# Extracted data for 90 mountains so far...
# Extracted lat/long text for Hachimantai: 39.957745, 140.854103 (Dec Deg)39° 57' 28'' N, 140° 51' 15'' E (DMS)487539 E, 4423078 N, Zone 54 (UTM)
# Extracted lat/long text for Aso-san: 32.884333, 131.103919 (Dec Deg)32° 53' 4'' N, 131° 6' 14'' E (DMS)696814 E, 3640427 N, Zone 52 (UTM)
# Extracted lat/long text for Hakkoda-san: 40.658933, 140.877276 (Dec Deg)40° 39' 32'' N, 140° 52' 38'' E (DMS)489626 E, 4500904 N, Zone 54 (UTM)
# Extracted lat/long text for Tanzawa-san: 35.47432, 139.162773 (Dec Deg)35° 28' 28'' N, 139° 9' 46'' E (DMS)333314 E, 3927197 N, Zone 54 (UTM)
# Extracted lat/long text for Shari-dake: 43.765711, 144.717708 (Dec Deg)43° 45' 57'' N, 144° 43' 4'' E (DMS)316299 E, 4848383 N, Zone 55 (UTM)
# Extracted lat/long text for Arashima-dake: 35.934278, 136.601237 (Dec Deg)35° 56' 3'' N, 136° 36' 4'' E (DMS)644441 E, 3977844 N, Zone 53 (UTM)
# Extracted lat/long text for Meakan-dake: 43.386433, 144.008627 (Dec Deg)43° 23' 11'' N, 144° 0' 31'' E (DMS)257705 E, 4808076 N, Zone 55 (UTM)
# Extracted lat/long text for Amagi-san: 34.862856, 139.001806 (Dec Deg)34° 51' 46'' N, 139° 0' 7'' E (DMS)317345 E, 3859656 N, Zone 54 (UTM)
# Extracted lat/long text for Ibuki-yama: 35.417856, 136.406373 (Dec Deg)35° 25' 4'' N, 136° 24' 23'' E (DMS)627682 E, 3920292 N, Zone 53 (UTM)
# Extracted lat/long text for Kaimon-dake: 31.179944, 130.528397 (Dec Deg)31° 10' 48'' N, 130° 31' 42'' E (DMS)645643 E, 3450550 N, Zone 52 (UTM)
# Extracted data for 100 mountains so far...
# Extracted lat/long text for Tsukuba-san: 36.225403, 140.106705 (Dec Deg)36° 13' 31'' N, 140° 6' 24'' E (DMS)419718 E, 4009319 N, Zone 54 (UTM)

# %%
q3df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 100
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      100 non-null    object
#  1   region    100 non-null    object
#  2   elev      100 non-null    int64
#  3   id        100 non-null    object
#  4   lat       100 non-null    float64
#  5   long      100 non-null    float64
#  6   elev_cat  100 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.2+ KB

# %%
q3df.head(3)
# Out:
#           name region  elev     id        lat        long elev_cat
# 0     Fuji-san  Kanto  3776  10882  35.360638  138.727347    Cat 4
# 2    Kita-dake  Chubu  3192  10866  35.674537  138.238833    Cat 4
# 3  Hotaka-dake  Chubu  3190  10840  36.289203  137.647986    Cat 4

# %%
q3df.tail(3)
# Out:
#             name         region  elev     id        lat        long elev_cat
# 98    Ibuki-yama  Western Japan  1377  10879  35.417856  136.406373    Cat 2
# 99   Kaimon-dake  Western Japan   924  10937  31.179944  130.528397    Cat 1
# 100  Tsukuba-san          Kanto   877  10844  36.225403  140.106705    Cat 1

# %%
q3sample
# Out:
# elev_cat       Cat 1  Cat 2  Cat 3  Cat 4
# region
# Chubu              0      4     29     12
# Hokkaido           0      5      4      0
# Kanto              1      3      8      1
# Tohoku             0     11      9      0
# Western Japan      1     12      0      0

# %%
import requests
from bs4 import BeautifulSoup

url = "https://masters.hkubs.hku.hk/articles/masterofscienceinbusinessanalytics/ourfaculty"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
divs = soup.find_all('div')  

for index, div in enumerate(divs[:5]):  
    print(f"Div {index}:")
    print(div.prettify())
    print("\n" + "="*80 + "\n")
# Out:
# Div 0:
# <div class="loadingPage__Animation-ukg194-1 gDolnq">
#  <div aria-label="animation" role="button" style="width:100%;height:100%;overflow:hidden;margin:0 auto;outline:none" tabindex="0" title="">
#  </div>
# </div>
#
#
# ================================================================================
#
# Div 1:
# <div aria-label="animation" role="button" style="width:100%;height:100%;overflow:hidden;margin:0 auto;outline:none" tabindex="0" title="">
# </div>
#
#
# ================================================================================
#
# Div 2:
# <div class="iHyclk">
#  <section class="sidebar__Overlay-sc-1e3pgs5-9 hdgGlQ">
#  </section>
#  <section class="sidebar__Wrapper-sc-1e3pgs5-10 dVAfLE">
#   <div style="position:relative;overflow:hidden;width:100%;height:100%">
#    <div style="position:absolute;top:0;left:0;right:0;bottom:0;overflow:hidden;-webkit-overflow-scrolling:touch;margin-right:0;margin-bottom:0">
#     <div class="sidebar__Navigation-sc-1e3pgs5-11 ezUfru false">
#      <div class="adlogo" style="margin-bottom: 6%;">
#       <a href="/">
#        <img src="/uploads/image/202207/06a15021779f99588cb18658b9c37d71.png" style="width: 200px;"/>
#       </a>
#       <strong>
#        Masters Programmes
#       </strong>
#      </div>
#      <ul class="sb-nav_list">
#       <li class="sb-nav_item -dropdownM">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/">
#           Home
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#       </li>
#       <li class="sb-nav_item -dropdownM">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/articles/aboutus">
#           About Us
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#        <div class="sb-nav_dropdown">
#         <div class="sb-nav_dropdown_wrap">
#          <ul class="sb-nav_dropdown_list">
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/facultymembershighlights">
#             Faculty Members' Highlights
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/facilities">
#             Facilities
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/aboutourmastersprogrammes">
#             About our Masters Programmes
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/aboutus">
#             Why HKU Business School
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="sb-nav_item -dropdownM">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/articles/masterofaccounting">
#           Our Programmes
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#        <div class="sb-nav_dropdown">
#         <div class="sb-nav_dropdown_wrap">
#          <ul class="sb-nav_dropdown_list">
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masterofaccounting">
#             Master of Accounting
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masterofclimategovernanceandriskmanagement">
#             Master of Climate Governance and Risk Management
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masterofeconomics">
#             Master of Economics
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masteroffamilywealthmanagement">
#             Master of Family Wealth Management
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masteroffinance">
#             Master of Finance
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masteroffinanceinfinancialtechnology">
#             Master of Finance in Financial Technology
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masterofglobalmanagement">
#             Master of Global Management
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masterofscienceinbusinessanalytics">
#             Master of Science in Business Analytics
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/masterofscienceinmarketing">
#             Master of Science in Marketing
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="sb-nav_item -dropdownM">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/articles/careersupport">
#           Career Support
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#        <div class="sb-nav_dropdown">
#         <div class="sb-nav_dropdown_wrap">
#          <ul class="sb-nav_dropdown_list">
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/iang">
#             Immigration Arrangements for Non-local Graduates
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/internshipopportunities">
#             Internship Opportunities
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/graduatedestinations">
#             Graduate Destinations
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/careerdevelopmenttrainingevents">
#             Career Development And Training Events
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/careersupport">
#             Career Development &amp; Training (CDT)
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="sb-nav_item -dropdownM">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/articles/wordsfromstudentsalumni">
#           Student Life
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#        <div class="sb-nav_dropdown">
#         <div class="sb-nav_dropdown_wrap">
#          <ul class="sb-nav_dropdown_list">
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/studentambassadorstudentclubs">
#             Student Ambassador and Student Clubs
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/mentorshipprogramme">
#             Mentorship Programme
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/studentalumniservices">
#             Alumni &amp; Student Activities
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/wordsfromstudentsalumni">
#             Words from Students &amp; Alumni
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/livinginhongkong">
#             Living In Hong Kong
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="sb-nav_item -dropdownM">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/articles/admissionsschedule">
#           Admissions
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#        <div class="sb-nav_dropdown">
#         <div class="sb-nav_dropdown_wrap">
#          <ul class="sb-nav_dropdown_list">
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/tpg">
#             Targeted Taught Postgraduate Programmes Fellowships Scheme
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/tuitionfeescholarships">
#             Tuition Fee &amp; Scholarships &amp; Financial Aid
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/application_procedures">
#             Application Procedure
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/upcoming_admissions_events">
#             Admissions Events
#            </a>
#           </li>
#           <li class="sb-nav_dropdown_item">
#            <a class="sb-nav_dropdown_link" href="/articles/admissionsschedule">
#             Admissions Requirements &amp; Schedule
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="sb-nav_item undefined">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="/articles/faq">
#           FAQs
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#       </li>
#       <li class="sb-nav_item undefined">
#        <div class="sb-nav_link">
#         <span class="sb-nav_link_text">
#          <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school">
#           Apply Now
#          </a>
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </div>
#       </li>
#       <li class="space">
#       </li>
#       <li class="sb-nav_item bottom">
#        <a class="sb-nav_link" href="https://www.hku.hk/">
#         <span class="sb-nav_link_text">
#          The University of Hong Kong
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </a>
#       </li>
#       <li class="sb-nav_item bottom">
#        <a class="sb-nav_link" href="https://www.hkubs.hku.hk/">
#         <span class="sb-nav_link_text">
#          HKU Business School
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </a>
#       </li>
#       <li class="sb-nav_item bottom">
#        <a class="sb-nav_link" href="mailto:fbemsc@hku.hk">
#         <span class="sb-nav_link_text">
#          Enquiry
#         </span>
#         <span class="sb-nav_link_line">
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="sidebar__NavigationResponsive-sc-1e3pgs5-12 eoBHhl">
#      <div class="sidebar__NavList-sc-1e3pgs5-13 crffqB">
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/">
#           Home
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/articles/aboutus">
#           About Us
#          </a>
#         </div>
#         <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#          <i class="icon-arrow4_down">
#          </i>
#         </div>
#        </div>
#        <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/facultymembershighlights">
#           Faculty Members' Highlights
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/facilities">
#           Facilities
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/aboutourmastersprogrammes">
#           About our Masters Programmes
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/aboutus">
#           Why HKU Business School
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/articles/masterofaccounting">
#           Our Programmes
#          </a>
#         </div>
#         <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#          <i class="icon-arrow4_down">
#          </i>
#         </div>
#        </div>
#        <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masterofaccounting">
#           Master of Accounting
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masterofclimategovernanceandriskmanagement">
#           Master of Climate Governance and Risk Management
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masterofeconomics">
#           Master of Economics
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masteroffamilywealthmanagement">
#           Master of Family Wealth Management
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masteroffinance">
#           Master of Finance
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masteroffinanceinfinancialtechnology">
#           Master of Finance in Financial Technology
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masterofglobalmanagement">
#           Master of Global Management
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masterofscienceinbusinessanalytics">
#           Master of Science in Business Analytics
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/masterofscienceinmarketing">
#           Master of Science in Marketing
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/articles/careersupport">
#           Career Support
#          </a>
#         </div>
#         <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#          <i class="icon-arrow4_down">
#          </i>
#         </div>
#        </div>
#        <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/iang">
#           Immigration Arrangements for Non-local Graduates
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/internshipopportunities">
#           Internship Opportunities
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/graduatedestinations">
#           Graduate Destinations
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/careerdevelopmenttrainingevents">
#           Career Development And Training Events
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/careersupport">
#           Career Development &amp; Training (CDT)
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/articles/wordsfromstudentsalumni">
#           Student Life
#          </a>
#         </div>
#         <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#          <i class="icon-arrow4_down">
#          </i>
#         </div>
#        </div>
#        <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/studentambassadorstudentclubs">
#           Student Ambassador and Student Clubs
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/mentorshipprogramme">
#           Mentorship Programme
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/studentalumniservices">
#           Alumni &amp; Student Activities
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/wordsfromstudentsalumni">
#           Words from Students &amp; Alumni
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/livinginhongkong">
#           Living In Hong Kong
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/articles/admissionsschedule">
#           Admissions
#          </a>
#         </div>
#         <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#          <i class="icon-arrow4_down">
#          </i>
#         </div>
#        </div>
#        <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/tpg">
#           Targeted Taught Postgraduate Programmes Fellowships Scheme
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/tuitionfeescholarships">
#           Tuition Fee &amp; Scholarships &amp; Financial Aid
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/application_procedures">
#           Application Procedure
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/upcoming_admissions_events">
#           Admissions Events
#          </a>
#         </div>
#         <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#          <a href="/articles/admissionsschedule">
#           Admissions Requirements &amp; Schedule
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="/articles/faq">
#           FAQs
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#          <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school">
#           Apply Now
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="space">
#       </div>
#       <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#          <a href="https://www.hku.hk/">
#           The University of Hong Kong
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#          <a href="https://www.hkubs.hku.hk/">
#           HKU Business School
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#        <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#         <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#          <a href="mailto:fbemsc@hku.hk">
#           Enquiry
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div style="position:absolute;height:6px;display:none;right:2px;bottom:2px;left:2px;border-radius:3px">
#     <div style="position:relative;display:block;height:100%;cursor:pointer;border-radius:inherit;background-color:rgba(0,0,0,.2)">
#     </div>
#    </div>
#    <div style="position:absolute;width:6px;display:none;right:2px;bottom:2px;top:2px;border-radius:3px">
#     <div style="position:relative;display:block;width:100%;cursor:pointer;border-radius:inherit;background-color:rgba(0,0,0,.2)">
#     </div>
#    </div>
#   </div>
#   <div class="sidebar__Actions-sc-1e3pgs5-14 kzqfQI">
#    <div class="sidebar__Buttons-sc-1e3pgs5-20 hDXekn">
#     <button aria-label="Menu" class="sidebar__Button-sc-1e3pgs5-24 kiaLon">
#      <div class="sidebar__Hamburguer-sc-1e3pgs5-21 kfwpHo">
#       <i class="icon-hamburguer">
#       </i>
#      </div>
#      <div class="sidebar__Arrow-sc-1e3pgs5-22 hwybnx">
#       <i class="icon-hover_hamburger">
#       </i>
#      </div>
#      <div class="sidebar__Close-sc-1e3pgs5-23 pmayo">
#       <i class="icon-menu_close">
#       </i>
#      </div>
#     </button>
#    </div>
#   </div>
#  </section>
#  <div class="sidebar__ActionsResponsive-sc-1e3pgs5-15 dEIPtB">
#   <div class="sidebar__Logos-sc-1e3pgs5-16 gOZvmn">
#    <a href="/">
#     <img src="/uploads/image/202207/5adeb34adbebee9cf5b0f40852251da6.png"/>
#    </a>
#   </div>
#   <div class="sidebar__Buttons-sc-1e3pgs5-20 hDXekn">
#    <button aria-label="Menu" class="sidebar__Button-sc-1e3pgs5-24 kiaLon">
#     <div class="sidebar__Hamburguer-sc-1e3pgs5-21 kfwpHo">
#      <i class="icon-hamburguer">
#      </i>
#     </div>
#     <div class="sidebar__Arrow-sc-1e3pgs5-22 hwybnx">
#      <i class="icon-hover_hamburger">
#      </i>
#     </div>
#     <div class="sidebar__Close-sc-1e3pgs5-23 pmayo">
#      <i class="icon-menu_close">
#      </i>
#     </div>
#    </button>
#   </div>
#  </div>
#  <div class="hover_apply">
#   <div class="apply wow fadeInDown">
#    <div class="apply_top">
#     <div class="apply_ico">
#      <img src="/themes/bingo/static/images/apply.png"/>
#     </div>
#     <div class="app_wz apply_bar_text">
#      <b>
#       Apply Now
#      </b>
#     </div>
#     <div class="app_wz apply_bar_url">
#      <b>
#       <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school" target="_blank">
#        Apply Now
#       </a>
#      </b>
#     </div>
#    </div>
#    <div class="apply_bottom">
#     <p class="application_deadline">
#      Application Deadline
#     </p>
#     <dl>
#      <dd>
#       <img src="/themes/bingo/static/images/ii1.png"/>
#       <b>
#        08th Oct,2024 Tuesday
#       </b>
#      </dd>
#      <dd>
#       <img src="/themes/bingo/static/images/ii2.png"/>
#       <b>
#        12
#        :00                            noon
#       </b>
#      </dd>
#     </dl>
#    </div>
#   </div>
#  </div>
# </div>
#
#
# ================================================================================
#
# Div 3:
# <div style="position:relative;overflow:hidden;width:100%;height:100%">
#  <div style="position:absolute;top:0;left:0;right:0;bottom:0;overflow:hidden;-webkit-overflow-scrolling:touch;margin-right:0;margin-bottom:0">
#   <div class="sidebar__Navigation-sc-1e3pgs5-11 ezUfru false">
#    <div class="adlogo" style="margin-bottom: 6%;">
#     <a href="/">
#      <img src="/uploads/image/202207/06a15021779f99588cb18658b9c37d71.png" style="width: 200px;"/>
#     </a>
#     <strong>
#      Masters Programmes
#     </strong>
#    </div>
#    <ul class="sb-nav_list">
#     <li class="sb-nav_item -dropdownM">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/">
#         Home
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#     </li>
#     <li class="sb-nav_item -dropdownM">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/articles/aboutus">
#         About Us
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#      <div class="sb-nav_dropdown">
#       <div class="sb-nav_dropdown_wrap">
#        <ul class="sb-nav_dropdown_list">
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/facultymembershighlights">
#           Faculty Members' Highlights
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/facilities">
#           Facilities
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/aboutourmastersprogrammes">
#           About our Masters Programmes
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/aboutus">
#           Why HKU Business School
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </li>
#     <li class="sb-nav_item -dropdownM">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/articles/masterofaccounting">
#         Our Programmes
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#      <div class="sb-nav_dropdown">
#       <div class="sb-nav_dropdown_wrap">
#        <ul class="sb-nav_dropdown_list">
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masterofaccounting">
#           Master of Accounting
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masterofclimategovernanceandriskmanagement">
#           Master of Climate Governance and Risk Management
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masterofeconomics">
#           Master of Economics
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masteroffamilywealthmanagement">
#           Master of Family Wealth Management
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masteroffinance">
#           Master of Finance
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masteroffinanceinfinancialtechnology">
#           Master of Finance in Financial Technology
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masterofglobalmanagement">
#           Master of Global Management
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masterofscienceinbusinessanalytics">
#           Master of Science in Business Analytics
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/masterofscienceinmarketing">
#           Master of Science in Marketing
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </li>
#     <li class="sb-nav_item -dropdownM">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/articles/careersupport">
#         Career Support
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#      <div class="sb-nav_dropdown">
#       <div class="sb-nav_dropdown_wrap">
#        <ul class="sb-nav_dropdown_list">
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/iang">
#           Immigration Arrangements for Non-local Graduates
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/internshipopportunities">
#           Internship Opportunities
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/graduatedestinations">
#           Graduate Destinations
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/careerdevelopmenttrainingevents">
#           Career Development And Training Events
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/careersupport">
#           Career Development &amp; Training (CDT)
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </li>
#     <li class="sb-nav_item -dropdownM">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/articles/wordsfromstudentsalumni">
#         Student Life
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#      <div class="sb-nav_dropdown">
#       <div class="sb-nav_dropdown_wrap">
#        <ul class="sb-nav_dropdown_list">
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/studentambassadorstudentclubs">
#           Student Ambassador and Student Clubs
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/mentorshipprogramme">
#           Mentorship Programme
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/studentalumniservices">
#           Alumni &amp; Student Activities
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/wordsfromstudentsalumni">
#           Words from Students &amp; Alumni
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/livinginhongkong">
#           Living In Hong Kong
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </li>
#     <li class="sb-nav_item -dropdownM">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/articles/admissionsschedule">
#         Admissions
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#      <div class="sb-nav_dropdown">
#       <div class="sb-nav_dropdown_wrap">
#        <ul class="sb-nav_dropdown_list">
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/tpg">
#           Targeted Taught Postgraduate Programmes Fellowships Scheme
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/tuitionfeescholarships">
#           Tuition Fee &amp; Scholarships &amp; Financial Aid
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/application_procedures">
#           Application Procedure
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/upcoming_admissions_events">
#           Admissions Events
#          </a>
#         </li>
#         <li class="sb-nav_dropdown_item">
#          <a class="sb-nav_dropdown_link" href="/articles/admissionsschedule">
#           Admissions Requirements &amp; Schedule
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </li>
#     <li class="sb-nav_item undefined">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="/articles/faq">
#         FAQs
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#     </li>
#     <li class="sb-nav_item undefined">
#      <div class="sb-nav_link">
#       <span class="sb-nav_link_text">
#        <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school">
#         Apply Now
#        </a>
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </div>
#     </li>
#     <li class="space">
#     </li>
#     <li class="sb-nav_item bottom">
#      <a class="sb-nav_link" href="https://www.hku.hk/">
#       <span class="sb-nav_link_text">
#        The University of Hong Kong
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </a>
#     </li>
#     <li class="sb-nav_item bottom">
#      <a class="sb-nav_link" href="https://www.hkubs.hku.hk/">
#       <span class="sb-nav_link_text">
#        HKU Business School
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </a>
#     </li>
#     <li class="sb-nav_item bottom">
#      <a class="sb-nav_link" href="mailto:fbemsc@hku.hk">
#       <span class="sb-nav_link_text">
#        Enquiry
#       </span>
#       <span class="sb-nav_link_line">
#       </span>
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="sidebar__NavigationResponsive-sc-1e3pgs5-12 eoBHhl">
#    <div class="sidebar__NavList-sc-1e3pgs5-13 crffqB">
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/">
#         Home
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/articles/aboutus">
#         About Us
#        </a>
#       </div>
#       <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#        <i class="icon-arrow4_down">
#        </i>
#       </div>
#      </div>
#      <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/facultymembershighlights">
#         Faculty Members' Highlights
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/facilities">
#         Facilities
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/aboutourmastersprogrammes">
#         About our Masters Programmes
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/aboutus">
#         Why HKU Business School
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/articles/masterofaccounting">
#         Our Programmes
#        </a>
#       </div>
#       <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#        <i class="icon-arrow4_down">
#        </i>
#       </div>
#      </div>
#      <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masterofaccounting">
#         Master of Accounting
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masterofclimategovernanceandriskmanagement">
#         Master of Climate Governance and Risk Management
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masterofeconomics">
#         Master of Economics
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masteroffamilywealthmanagement">
#         Master of Family Wealth Management
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masteroffinance">
#         Master of Finance
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masteroffinanceinfinancialtechnology">
#         Master of Finance in Financial Technology
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masterofglobalmanagement">
#         Master of Global Management
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masterofscienceinbusinessanalytics">
#         Master of Science in Business Analytics
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/masterofscienceinmarketing">
#         Master of Science in Marketing
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/articles/careersupport">
#         Career Support
#        </a>
#       </div>
#       <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#        <i class="icon-arrow4_down">
#        </i>
#       </div>
#      </div>
#      <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/iang">
#         Immigration Arrangements for Non-local Graduates
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/internshipopportunities">
#         Internship Opportunities
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/graduatedestinations">
#         Graduate Destinations
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/careerdevelopmenttrainingevents">
#         Career Development And Training Events
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/careersupport">
#         Career Development &amp; Training (CDT)
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/articles/wordsfromstudentsalumni">
#         Student Life
#        </a>
#       </div>
#       <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#        <i class="icon-arrow4_down">
#        </i>
#       </div>
#      </div>
#      <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/studentambassadorstudentclubs">
#         Student Ambassador and Student Clubs
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/mentorshipprogramme">
#         Mentorship Programme
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/studentalumniservices">
#         Alumni &amp; Student Activities
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/wordsfromstudentsalumni">
#         Words from Students &amp; Alumni
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/livinginhongkong">
#         Living In Hong Kong
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/articles/admissionsschedule">
#         Admissions
#        </a>
#       </div>
#       <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#        <i class="icon-arrow4_down">
#        </i>
#       </div>
#      </div>
#      <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/tpg">
#         Targeted Taught Postgraduate Programmes Fellowships Scheme
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/tuitionfeescholarships">
#         Tuition Fee &amp; Scholarships &amp; Financial Aid
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/application_procedures">
#         Application Procedure
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/upcoming_admissions_events">
#         Admissions Events
#        </a>
#       </div>
#       <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#        <a href="/articles/admissionsschedule">
#         Admissions Requirements &amp; Schedule
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="/articles/faq">
#         FAQs
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#        <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school">
#         Apply Now
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="space">
#     </div>
#     <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#        <a href="https://www.hku.hk/">
#         The University of Hong Kong
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#        <a href="https://www.hkubs.hku.hk/">
#         HKU Business School
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#      <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#       <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#        <a href="mailto:fbemsc@hku.hk">
#         Enquiry
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div style="position:absolute;height:6px;display:none;right:2px;bottom:2px;left:2px;border-radius:3px">
#   <div style="position:relative;display:block;height:100%;cursor:pointer;border-radius:inherit;background-color:rgba(0,0,0,.2)">
#   </div>
#  </div>
#  <div style="position:absolute;width:6px;display:none;right:2px;bottom:2px;top:2px;border-radius:3px">
#   <div style="position:relative;display:block;width:100%;cursor:pointer;border-radius:inherit;background-color:rgba(0,0,0,.2)">
#   </div>
#  </div>
# </div>
#
#
# ================================================================================
#
# Div 4:
# <div style="position:absolute;top:0;left:0;right:0;bottom:0;overflow:hidden;-webkit-overflow-scrolling:touch;margin-right:0;margin-bottom:0">
#  <div class="sidebar__Navigation-sc-1e3pgs5-11 ezUfru false">
#   <div class="adlogo" style="margin-bottom: 6%;">
#    <a href="/">
#     <img src="/uploads/image/202207/06a15021779f99588cb18658b9c37d71.png" style="width: 200px;"/>
#    </a>
#    <strong>
#     Masters Programmes
#    </strong>
#   </div>
#   <ul class="sb-nav_list">
#    <li class="sb-nav_item -dropdownM">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/">
#        Home
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#    </li>
#    <li class="sb-nav_item -dropdownM">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/articles/aboutus">
#        About Us
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#     <div class="sb-nav_dropdown">
#      <div class="sb-nav_dropdown_wrap">
#       <ul class="sb-nav_dropdown_list">
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/facultymembershighlights">
#          Faculty Members' Highlights
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/facilities">
#          Facilities
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/aboutourmastersprogrammes">
#          About our Masters Programmes
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/aboutus">
#          Why HKU Business School
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </li>
#    <li class="sb-nav_item -dropdownM">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/articles/masterofaccounting">
#        Our Programmes
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#     <div class="sb-nav_dropdown">
#      <div class="sb-nav_dropdown_wrap">
#       <ul class="sb-nav_dropdown_list">
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masterofaccounting">
#          Master of Accounting
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masterofclimategovernanceandriskmanagement">
#          Master of Climate Governance and Risk Management
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masterofeconomics">
#          Master of Economics
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masteroffamilywealthmanagement">
#          Master of Family Wealth Management
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masteroffinance">
#          Master of Finance
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masteroffinanceinfinancialtechnology">
#          Master of Finance in Financial Technology
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masterofglobalmanagement">
#          Master of Global Management
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masterofscienceinbusinessanalytics">
#          Master of Science in Business Analytics
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/masterofscienceinmarketing">
#          Master of Science in Marketing
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </li>
#    <li class="sb-nav_item -dropdownM">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/articles/careersupport">
#        Career Support
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#     <div class="sb-nav_dropdown">
#      <div class="sb-nav_dropdown_wrap">
#       <ul class="sb-nav_dropdown_list">
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/iang">
#          Immigration Arrangements for Non-local Graduates
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/internshipopportunities">
#          Internship Opportunities
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/graduatedestinations">
#          Graduate Destinations
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/careerdevelopmenttrainingevents">
#          Career Development And Training Events
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/careersupport">
#          Career Development &amp; Training (CDT)
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </li>
#    <li class="sb-nav_item -dropdownM">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/articles/wordsfromstudentsalumni">
#        Student Life
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#     <div class="sb-nav_dropdown">
#      <div class="sb-nav_dropdown_wrap">
#       <ul class="sb-nav_dropdown_list">
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/studentambassadorstudentclubs">
#          Student Ambassador and Student Clubs
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/mentorshipprogramme">
#          Mentorship Programme
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/studentalumniservices">
#          Alumni &amp; Student Activities
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/wordsfromstudentsalumni">
#          Words from Students &amp; Alumni
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/livinginhongkong">
#          Living In Hong Kong
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </li>
#    <li class="sb-nav_item -dropdownM">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/articles/admissionsschedule">
#        Admissions
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#     <div class="sb-nav_dropdown">
#      <div class="sb-nav_dropdown_wrap">
#       <ul class="sb-nav_dropdown_list">
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/tpg">
#          Targeted Taught Postgraduate Programmes Fellowships Scheme
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/tuitionfeescholarships">
#          Tuition Fee &amp; Scholarships &amp; Financial Aid
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/application_procedures">
#          Application Procedure
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/upcoming_admissions_events">
#          Admissions Events
#         </a>
#        </li>
#        <li class="sb-nav_dropdown_item">
#         <a class="sb-nav_dropdown_link" href="/articles/admissionsschedule">
#          Admissions Requirements &amp; Schedule
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </li>
#    <li class="sb-nav_item undefined">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="/articles/faq">
#        FAQs
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#    </li>
#    <li class="sb-nav_item undefined">
#     <div class="sb-nav_link">
#      <span class="sb-nav_link_text">
#       <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school">
#        Apply Now
#       </a>
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </div>
#    </li>
#    <li class="space">
#    </li>
#    <li class="sb-nav_item bottom">
#     <a class="sb-nav_link" href="https://www.hku.hk/">
#      <span class="sb-nav_link_text">
#       The University of Hong Kong
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </a>
#    </li>
#    <li class="sb-nav_item bottom">
#     <a class="sb-nav_link" href="https://www.hkubs.hku.hk/">
#      <span class="sb-nav_link_text">
#       HKU Business School
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </a>
#    </li>
#    <li class="sb-nav_item bottom">
#     <a class="sb-nav_link" href="mailto:fbemsc@hku.hk">
#      <span class="sb-nav_link_text">
#       Enquiry
#      </span>
#      <span class="sb-nav_link_line">
#      </span>
#     </a>
#    </li>
#   </ul>
#  </div>
#  <div class="sidebar__NavigationResponsive-sc-1e3pgs5-12 eoBHhl">
#   <div class="sidebar__NavList-sc-1e3pgs5-13 crffqB">
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/">
#        Home
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/articles/aboutus">
#        About Us
#       </a>
#      </div>
#      <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#       <i class="icon-arrow4_down">
#       </i>
#      </div>
#     </div>
#     <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/facultymembershighlights">
#        Faculty Members' Highlights
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/facilities">
#        Facilities
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/aboutourmastersprogrammes">
#        About our Masters Programmes
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/aboutus">
#        Why HKU Business School
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/articles/masterofaccounting">
#        Our Programmes
#       </a>
#      </div>
#      <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#       <i class="icon-arrow4_down">
#       </i>
#      </div>
#     </div>
#     <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masterofaccounting">
#        Master of Accounting
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masterofclimategovernanceandriskmanagement">
#        Master of Climate Governance and Risk Management
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masterofeconomics">
#        Master of Economics
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masteroffamilywealthmanagement">
#        Master of Family Wealth Management
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masteroffinance">
#        Master of Finance
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masteroffinanceinfinancialtechnology">
#        Master of Finance in Financial Technology
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masterofglobalmanagement">
#        Master of Global Management
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masterofscienceinbusinessanalytics">
#        Master of Science in Business Analytics
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/masterofscienceinmarketing">
#        Master of Science in Marketing
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/articles/careersupport">
#        Career Support
#       </a>
#      </div>
#      <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#       <i class="icon-arrow4_down">
#       </i>
#      </div>
#     </div>
#     <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/iang">
#        Immigration Arrangements for Non-local Graduates
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/internshipopportunities">
#        Internship Opportunities
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/graduatedestinations">
#        Graduate Destinations
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/careerdevelopmenttrainingevents">
#        Career Development And Training Events
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/careersupport">
#        Career Development &amp; Training (CDT)
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/articles/wordsfromstudentsalumni">
#        Student Life
#       </a>
#      </div>
#      <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#       <i class="icon-arrow4_down">
#       </i>
#      </div>
#     </div>
#     <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/studentambassadorstudentclubs">
#        Student Ambassador and Student Clubs
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/mentorshipprogramme">
#        Mentorship Programme
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/studentalumniservices">
#        Alumni &amp; Student Activities
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/wordsfromstudentsalumni">
#        Words from Students &amp; Alumni
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/livinginhongkong">
#        Living In Hong Kong
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/articles/admissionsschedule">
#        Admissions
#       </a>
#      </div>
#      <div class="sidebar__DropdownHeaderArrow-sc-1e3pgs5-6 itvqoO">
#       <i class="icon-arrow4_down">
#       </i>
#      </div>
#     </div>
#     <div class="sidebar__DropdownContent-sc-1e3pgs5-7 fEWrpz">
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/tpg">
#        Targeted Taught Postgraduate Programmes Fellowships Scheme
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/tuitionfeescholarships">
#        Tuition Fee &amp; Scholarships &amp; Financial Aid
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/application_procedures">
#        Application Procedure
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/upcoming_admissions_events">
#        Admissions Events
#       </a>
#      </div>
#      <div class="sidebar__DropdownContentItem-sc-1e3pgs5-8 gQrpwf">
#       <a href="/articles/admissionsschedule">
#        Admissions Requirements &amp; Schedule
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="/articles/faq">
#        FAQs
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__Dropdown-sc-1e3pgs5-1 etZwtC">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitle-sc-1e3pgs5-4 jXfWRM">
#       <a href="https://admissions.hku.hk/tpg/faculty/hku-business-school">
#        Apply Now
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="space">
#    </div>
#    <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#       <a href="https://www.hku.hk/">
#        The University of Hong Kong
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#       <a href="https://www.hkubs.hku.hk/">
#        HKU Business School
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="sidebar__DropdownMiddle-sc-1e3pgs5-2 irALaM">
#     <div class="sidebar__DropdownHeader-sc-1e3pgs5-3 gdjsjX">
#      <div class="sidebar__DropdownHeaderTitleLast-sc-1e3pgs5-5 tcYQb">
#       <a href="mailto:fbemsc@hku.hk">
#        Enquiry
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>
#
#
# ================================================================================

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import os
import time
import requests

service = Service(ChromeDriverManager().install())  
driver = webdriver.Chrome(service=service)

url = 'https://masters.hkubs.hku.hk/articles/masterofscienceinbusinessanalytics/ourfaculty'
driver.get(url)

time.sleep(5)

soup = BeautifulSoup(driver.page_source, 'html.parser')

professors = []

for profile in soup.find_all('div', class_='col-md-4'):
    link = profile.find('a', class_='boximg')
    name_tag = link.find('b', class_='name')
    phd_tag = link.find('p', class_='desinfo')
    image_tag = link.find('img')
    name = name_tag.text.strip() if name_tag else "Unknown"
    phd_university = phd_tag.text.strip() if phd_tag else "Unknown"
    image_url = image_tag['src'] if image_tag else ""

    professors.append({
        'name': name,
        'phd_university': phd_university,
        'image_url': image_url
    })

driver.quit()

q4df = pd.DataFrame(professors)

os.makedirs('images', exist_ok=True)

for i, row in q4df.iterrows():
    image_url = row['image_url']
    name = row['name'].replace(' ', '_') + '.jpg'  
    image_path = os.path.join('images', name)
    
    if image_url:
        try:
            img_response = requests.get('https://masters.hkubs.hku.hk' + image_url) 
            with open(image_path, 'wb') as img_file:
                img_file.write(img_response.content)
        except Exception as e:
            print(f"Failed to download image for {row['name']}: {e}")

q4df.to_csv('Q4_teachers.csv', index=False)
# Out:
#                                                 name  \
# 0                                  Prof. Boris Babic
# 1                                  Prof. Zhanrui CAI
# 2                           Prof. Michael C. L. CHAU
# 3  Prof. Hailiang CHEN, Assistant Dean (Taught Po...
# 4                                    Prof. Chao DING
#
#                                       phd_university  \
# 0             JD., Harvard Law School, United States
# 1  Ph.D., The Pennsylvania State University, Unit...
# 2           Ph.D., Arizona University, United States
# 3            Ph.D., Purdue University, United States
# 4        Ph.D., University of Florida, United States
#
#                                            image_url
# 0  /uploads/image/202409/af79edec8240dc022014af59...
# 1  /uploads/image/202408/45326d58ed53b6ad2afb7adf...
# 2  /uploads/image/202205/ac5d364416b5bb9a1714038c...
# 3  /uploads/image/202205/7bf2456efbfe30faf679e868...
# 4  /uploads/image/202205/caadde230670b19f303e4d28...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            28 non-null     object
#  1   phd_university  28 non-null     object
#  2   image_url       28 non-null     object
# dtypes: object(3)
# memory usage: 804.0+ bytes
# None

# %%
q4df.head()
# Out:
#                                                 name  \
# 0                                  Prof. Boris Babic
# 1                                  Prof. Zhanrui CAI
# 2                           Prof. Michael C. L. CHAU
# 3  Prof. Hailiang CHEN, Assistant Dean (Taught Po...
# 4                                    Prof. Chao DING
#
#                                       phd_university  \
# 0             JD., Harvard Law School, United States
# 1  Ph.D., The Pennsylvania State University, Unit...
# 2           Ph.D., Arizona University, United States
# 3            Ph.D., Purdue University, United States
# 4        Ph.D., University of Florida, United States
#
#                                            image_url
# 0  /uploads/image/202409/af79edec8240dc022014af59...
# 1  /uploads/image/202408/45326d58ed53b6ad2afb7adf...
# 2  /uploads/image/202205/ac5d364416b5bb9a1714038c...
# 3  /uploads/image/202205/7bf2456efbfe30faf679e868...
# 4  /uploads/image/202205/caadde230670b19f303e4d28...

# %%
q4df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            28 non-null     object
#  1   phd_university  28 non-null     object
#  2   image_url       28 non-null     object
# dtypes: object(3)
# memory usage: 804.0+ bytes
